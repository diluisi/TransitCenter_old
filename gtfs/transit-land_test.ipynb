# %%
import requests
import csv
import os
import urllib
import sys
import importlib
import pandas as pd

sys.path.insert(1, '../utils')

import utils

# %%
importlib.reload(utils)
# Out:
# <module 'utils' from '../utils/utils.py'>

# %%
region = 'Philadelphia'
extent = 'core'
county_ids = utils.county_ids.get_county_ids(region, extent)
input_date = '2020-05-01'
xmin, xmax, ymin, ymax = utils.geometry.osm_bounds(region, county_ids, extent, file = False, raw = True)

# %%
input_date_int = 10000 * int(input_date[0:4]) + 100 * int(input_date[5:7]) + int(input_date[8:10])

# query to find all locations within the bounding box of our region

response = requests.get(
    "https://transit.land/api/v1/operators",
    params = {
        "bbox": str(xmin) + "," + str(ymin) + "," + str(xmax) + "," + str(ymax) # from the previous section
    }
)
all_operators_json = response.json()
all_operators_json = all_operators_json["operators"]

# loop over operators, adding unique feed info (based on onestop_id) to a list

feed_base_info = []
for operator in all_operators_json:
    for onestop_id in operator["represented_in_feed_onestop_ids"]:
        feed_base_info.append([onestop_id, operator["name"],operator["website"],operator["state"],operator["metro"],operator["timezone"]])

# %%
feed_info = feed_base_info[2]

# %%
# loop over feed info, getting info for each feed, and saving to an output array

output_feed_info = [["operator_name", "operator_website", "operator_state", "operator_metro", "operator_timezone", "transitland_feed_id", "date_fetched", "earliest_calendar_date", "latest_calendar_date", "transitland_historical_url"]]

    # base info
operator_name = feed_info[1]
operator_website = feed_info[2]
operator_state = feed_info[3]
operator_metro = feed_info[4]
operator_timezone = feed_info[5]

# get feed versions
response = requests.get(
"https://transit.land/api/v1/feed_versions",
params = {
    "feed_onestop_id": feed_info[0],
    "per_page": 999
    }
)        
feeds = response.json()
#sleep(1) # to avoid API timeout

# if there are feeds, find the feed that is the most recent to the input date

# %%
feeds
# Out:
# {'feed_versions': [{'sha1': 'e64945dd7e50262b5cf40e3be84a62d6cba7f25a',
#    'earliest_calendar_date': '2016-02-18',
#    'latest_calendar_date': '2016-06-18',
#    'md5': '20fb24c2477ce31ca773b8c360ad2a5b',
#    'tags': None,
#    'fetched_at': '2016-05-09T19:43:01.916Z',
#    'imported_at': '2016-05-09T21:38:42.553Z',
#    'import_level': 4,
#    'created_at': '2016-05-09T19:43:08.752Z',
#    'updated_at': '2017-04-29T09:37:01.952Z',
#    'feed_version_imports': [481],
#    'feed_version_imports_url': 'https://api.transit.land/api/v1/feed_version_imports?feed_onestop_id=f-dr4-septa%7Ebus&feed_version_sha1=e64945dd7e50262b5cf40e3be84a62d6cba7f25a',
#    'feed_version_infos': [1704, 6944],
#    'import_status': 'most_recent_succeeded',
#    'is_active_feed_version': False,
#    'changesets_imported_from_this_feed_version': [1336],
#    'feed': 'f-dr4-septa~bus',
#    'url': 'https://github.com/septadev/GTFS/releases/download/v20160425.2/gtfs_public.zip#google_bus.zip',
#    'download_url': 'https://transitland-gtfs.s3.amazonaws.com/datastore-uploads/feed_version/e64945dd7e50262b5cf40e3be84a62d6cba7f25a.zip',
#    'feedvalidator_url': 'https://transitland-gtfs.s3.amazonaws.com/datastore-uploads/feed_version/e64945dd7e50262b5cf40e3be84a62d6cba7f25a-feedvalidator.html'},
#   {'sha1': 'c92ba3dd259e9705e345518e4f38fa62ba8d3c8d',
#    'earliest_calendar_date': '2016-06-19',
#    'latest_calendar_date': '2016-09-03',
#    'md5': '5633085f314e448c10d6ab9a4ead925e',
#    'tags': None,
#    'fetched_at': '2016-06-20T18:34:44.665Z',
#    'imported_at': '2016-06-21T01:37:48.673Z',
#    'import_level': 4,
#    'created_at': '2016-06-20T18:35:48.134Z',
#    'updated_at': '2017-04-29T09:35:20.449Z',
#    'feed_version_imports': [611],
#    'feed_version_imports_url': 'https://api.transit.land/api/v1/feed_version_imports?feed_onestop_id=f-dr4-septa%7Ebus&feed_version_sha1=c92ba3dd259e9705e345518e4f38fa62ba8d3c8d',
#    'feed_version_infos': [2102, 6943],
#    'import_status': 'most_recent_succeeded',
#    'is_active_feed_version': False,
#    'changesets_imported_from_this_feed_version': [1577],
#    'feed': 'f-dr4-septa~bus',
#    'url': 'https://github.com/septadev/GTFS/releases/download/v20160619/gtfs_public.zip#google_bus.zip',
#    'download_url': 'https://transitland-gtfs.s3.amazonaws.com/datastore-uploads/feed_version/c92ba3dd259e9705e345518e4f38fa62ba8d3c8d.zip',
#    'feedvalidator_url': 'https://transitland-gtfs.s3.amazonaws.com/datastore-uploads/feed_version/c92ba3dd259e9705e345518e4f38fa62ba8d3c8d-feedvalidator.html'},
#   {'sha1': 'ba43f442b18b66f95ea594ba80f35b92bbfd3283',
#    'earliest_calendar_date': '2016-09-04',
#    'latest_calendar_date': '2017-02-25',
#    'md5': '660df7c25f6a243ef0e80b0297ab3d55',
#    'tags': None,
#    'fetched_at': '2016-08-31T06:32:28.484Z',
#    'imported_at': '2016-09-02T12:25:21.599Z',
#    'import_level': 4,
#    'created_at': '2016-08-31T06:32:38.881Z',
#    'updated_at': '2017-05-01T11:43:17.868Z',
#    'feed_version_imports': [1187],
#    'feed_version_imports_url': 'https://api.transit.land/api/v1/feed_version_imports?feed_onestop_id=f-dr4-septa%7Ebus&feed_version_sha1=ba43f442b18b66f95ea594ba80f35b92bbfd3283',
#    'feed_version_infos': [2989, 8630],
#    'import_status': 'most_recent_succeeded',
#    'is_active_feed_version': False,
#    'changesets_imported_from_this_feed_version': [2331],
#    'feed': 'f-dr4-septa~bus',
#    'url': 'https://github.com/septadev/GTFS/releases/download/V20160904/gtfs_public.zip#google_bus.zip',
#    'download_url': 'https://transitland-gtfs.s3.amazonaws.com/datastore-uploads/feed_version/ba43f442b18b66f95ea594ba80f35b92bbfd3283.zip',
#    'feedvalidator_url': 'https://transitland-gtfs.s3.amazonaws.com/datastore-uploads/feed_version/ba43f442b18b66f95ea594ba80f35b92bbfd3283-feedvalidator.html'},
#   {'sha1': 'dfdf4023b97aaabef774c681d7074478a52cad43',
#    'earliest_calendar_date': '2016-09-04',
#    'latest_calendar_date': '2017-02-25',
#    'md5': '4c30d306ca20a049f8d66c2549388b05',
#    'tags': {'extend_to_date': '2018-02-25', 'extend_from_date': '2017-01-25'},
#    'fetched_at': '2016-12-28T00:20:42.839Z',
#    'imported_at': '2017-01-27T06:37:42.499Z',
#    'import_level': 4,
#    'created_at': '2016-12-28T00:20:45.655Z',
#    'updated_at': '2017-05-11T12:37:58.373Z',
#    'feed_version_imports': [2899, 2492],
#    'feed_version_imports_url': 'https://api.transit.land/api/v1/feed_version_imports?feed_onestop_id=f-dr4-septa%7Ebus&feed_version_sha1=dfdf4023b97aaabef774c681d7074478a52cad43',
#    'feed_version_infos': [14586, 19813],
#    'import_status': 'most_recent_succeeded',
#    'is_active_feed_version': False,
#    'changesets_imported_from_this_feed_version': [3876, 4297],
#    'feed': 'f-dr4-septa~bus',
#    'url': 'https://github.com/septadev/GTFS/releases/download/v20161216/gtfs_public.zip#google_bus.zip',
#    'download_url': 'https://transitland-gtfs.s3.amazonaws.com/datastore-uploads/feed_version/dfdf4023b97aaabef774c681d7074478a52cad43.zip',
#    'feedvalidator_url': 'https://transitland-gtfs.s3.amazonaws.com/datastore-uploads/feed_version/dfdf4023b97aaabef774c681d7074478a52cad43-feedvalidator.html'},
#   {'sha1': '0db40fd8573b8f8677c274316f4a0c1091f582eb',
#    'earliest_calendar_date': '2016-09-04',
#    'latest_calendar_date': '2017-02-25',
#    'md5': '6e4eeac38e554c8d2265a27c7e942f49',
#    'tags': {'extend_to_date': '2018-02-25', 'extend_from_date': '2017-01-25'},
#    'fetched_at': '2017-01-27T16:13:15.934Z',
#    'imported_at': '2017-02-26T02:33:02.841Z',
#    'import_level': 4,
#    'created_at': '2017-01-27T16:13:16.510Z',
#    'updated_at': '2017-05-06T10:17:44.812Z',
#    'feed_version_imports': [3351],
#    'feed_version_imports_url': 'https://api.transit.land/api/v1/feed_version_imports?feed_onestop_id=f-dr4-septa%7Ebus&feed_version_sha1=0db40fd8573b8f8677c274316f4a0c1091f582eb',
#    'feed_version_infos': [12413, 16171],
#    'import_status': 'most_recent_succeeded',
#    'is_active_feed_version': False,
#    'changesets_imported_from_this_feed_version': [4821],
#    'feed': 'f-dr4-septa~bus',
#    'url': 'https://github.com/septadev/GTFS/releases/download/v20170129/gtfs_public.zip#google_bus.zip',
#    'download_url': 'https://transitland-gtfs.s3.amazonaws.com/datastore-uploads/feed_version/0db40fd8573b8f8677c274316f4a0c1091f582eb.zip',
#    'feedvalidator_url': 'https://transitland-gtfs.s3.amazonaws.com/datastore-uploads/feed_version/0db40fd8573b8f8677c274316f4a0c1091f582eb-feedvalidator.html'},
#   {'sha1': 'ab59cdb3a0e17ffad06d67eebb70b9a1375c52ea',
#    'earliest_calendar_date': '2017-02-26',
#    'latest_calendar_date': '2017-06-17',
#    'md5': 'ec79eca0cc93c3afdc7f67bbb3cd2a0b',
#    'tags': {},
#    'fetched_at': '2017-03-01T01:17:59.071Z',
#    'imported_at': '2017-04-06T22:46:53.759Z',
#    'import_level': 4,
#    'created_at': '2017-03-01T01:17:59.226Z',
#    'updated_at': '2017-05-07T00:29:43.805Z',
#    'feed_version_imports': [3879, 3385],
#    'feed_version_imports_url': 'https://api.transit.land/api/v1/feed_version_imports?feed_onestop_id=f-dr4-septa%7Ebus&feed_version_sha1=ab59cdb3a0e17ffad06d67eebb70b9a1375c52ea',
#    'feed_version_infos': [79, 13144],
#    'import_status': 'most_recent_succeeded',
#    'is_active_feed_version': False,
#    'changesets_imported_from_this_feed_version': [5351, 4856],
#    'feed': 'f-dr4-septa~bus',
#    'url': 'https://github.com/septadev/GTFS/releases/download/v20170226/gtfs_public.zip#google_bus.zip',
#    'download_url': 'https://transitland-gtfs.s3.amazonaws.com/datastore-uploads/feed_version/ab59cdb3a0e17ffad06d67eebb70b9a1375c52ea.zip',
#    'feedvalidator_url': 'https://transitland-gtfs.s3.amazonaws.com/datastore-uploads/feed_version/ab59cdb3a0e17ffad06d67eebb70b9a1375c52ea-feedvalidator.html'},
#   {'sha1': 'ad8e5143612fab952b5d7ef3f8d861c6df399ec7',
#    'earliest_calendar_date': '2017-02-26',
#    'latest_calendar_date': '2017-06-17',
#    'md5': 'f1da312af1e1cc006ffa423b1eb9826c',
#    'tags': {'extend_to_date': '2018-06-17', 'extend_from_date': '2017-05-17'},
#    'fetched_at': '2017-05-05T17:51:15.218Z',
#    'imported_at': '2017-05-18T06:00:48.319Z',
#    'import_level': 4,
#    'created_at': '2017-05-05T17:51:15.145Z',
#    'updated_at': '2017-06-10T14:13:37.433Z',
#    'feed_version_imports': [4479, 4273],
#    'feed_version_imports_url': 'https://api.transit.land/api/v1/feed_version_imports?feed_onestop_id=f-dr4-septa%7Ebus&feed_version_sha1=ad8e5143612fab952b5d7ef3f8d861c6df399ec7',
#    'feed_version_infos': [16608, 16613],
#    'import_status': 'most_recent_succeeded',
#    'is_active_feed_version': False,
#    'changesets_imported_from_this_feed_version': [5803, 6025],
#    'feed': 'f-dr4-septa~bus',
#    'url': 'https://github.com/septadev/GTFS/releases/download/v20170423.1/gtfs_public.zip#google_bus.zip',
#    'download_url': 'https://transitland-gtfs.s3.amazonaws.com/datastore-uploads/feed_version/ad8e5143612fab952b5d7ef3f8d861c6df399ec7.zip',
#    'feedvalidator_url': 'https://transitland-gtfs.s3.amazonaws.com/datastore-uploads/feed_version/ad8e5143612fab952b5d7ef3f8d861c6df399ec7-feedvalidator.html'},
#   {'sha1': '12ef207f5b550185716fc025b870addcba5261d2',
#    'earliest_calendar_date': '2017-06-18',
#    'latest_calendar_date': '2017-09-02',
#    'md5': 'b08601c5b2360c42c51d8c365283ec8b',
#    'tags': {'extend_to_date': '2018-09-02', 'extend_from_date': '2017-08-02'},
#    'fetched_at': '2017-06-12T02:58:48.702Z',
#    'imported_at': '2017-06-15T19:45:34.258Z',
#    'import_level': 4,
#    'created_at': '2017-06-12T02:58:48.696Z',
#    'updated_at': '2017-08-26T14:14:55.801Z',
#    'feed_version_imports': [4756],
#    'feed_version_imports_url': 'https://api.transit.land/api/v1/feed_version_imports?feed_onestop_id=f-dr4-septa%7Ebus&feed_version_sha1=12ef207f5b550185716fc025b870addcba5261d2',
#    'feed_version_infos': [21235, 21234],
#    'import_status': 'most_recent_succeeded',
#    'is_active_feed_version': False,
#    'changesets_imported_from_this_feed_version': [6325],
#    'feed': 'f-dr4-septa~bus',
#    'url': 'https://github.com/septadev/GTFS/releases/download/v20170618/gtfs_public.zip#google_bus.zip',
#    'download_url': 'https://transitland-gtfs.s3.amazonaws.com/datastore-uploads/feed_version/12ef207f5b550185716fc025b870addcba5261d2.zip',
#    'feedvalidator_url': 'https://transitland-gtfs.s3.amazonaws.com/datastore-uploads/feed_version/12ef207f5b550185716fc025b870addcba5261d2-feedvalidator.html'},
#   {'sha1': 'da2c8f5aace0864a93079be2c4f976da4ebf575c',
#    'earliest_calendar_date': '2017-05-29',
#    'latest_calendar_date': '2017-09-02',
#    'md5': 'f43fdcb03722eff80bd299a4f1929bfc',
#    'tags': {},
#    'fetched_at': '2017-08-15T19:16:09.889Z',
#    'imported_at': None,
#    'import_level': 0,
#    'created_at': '2017-08-15T19:16:09.881Z',
#    'updated_at': '2017-08-15T19:17:28.059Z',
#    'feed_version_imports': [],
#    'feed_version_imports_url': 'https://api.transit.land/api/v1/feed_version_imports?feed_onestop_id=f-dr4-septa%7Ebus&feed_version_sha1=da2c8f5aace0864a93079be2c4f976da4ebf575c',
#    'feed_version_infos': [32024, 32025],
#    'import_status': 'never_imported',
#    'is_active_feed_version': False,
#    'changesets_imported_from_this_feed_version': [],
#    'feed': 'f-dr4-septa~bus',
#    'url': 'https://github.com/septadev/GTFS/releases/download/v20170701/gtfs_public.zip#google_bus.zip',
#    'download_url': 'https://transitland-gtfs.s3.amazonaws.com/datastore-uploads/feed_version/da2c8f5aace0864a93079be2c4f976da4ebf575c.zip',
#    'feedvalidator_url': 'https://transitland-gtfs.s3.amazonaws.com/datastore-uploads/feed_version/da2c8f5aace0864a93079be2c4f976da4ebf575c-feedvalidator.html'},
#   {'sha1': 'e07e3cacbf185bb6f00fff68c20fc044f8548a18',
#    'earliest_calendar_date': '2018-06-10',
#    'latest_calendar_date': '2018-08-25',
#    'md5': '7b1604ea9316be3d223ef9d6e314414e',
#    'tags': {},
#    'fetched_at': '2018-08-17T18:45:43.448Z',
#    'imported_at': None,
#    'import_level': 0,
#    'created_at': '2018-08-17T18:45:43.460Z',
#    'updated_at': '2018-08-17T18:45:43.620Z',
#    'feed_version_imports': [9932],
#    'feed_version_imports_url': 'https://api.transit.land/api/v1/feed_version_imports?feed_onestop_id=f-dr4-septa%7Ebus&feed_version_sha1=e07e3cacbf185bb6f00fff68c20fc044f8548a18',
#    'feed_version_infos': [52092],
#    'import_status': 'most_recent_failed',
#    'is_active_feed_version': False,
#    'changesets_imported_from_this_feed_version': [],
#    'feed': 'f-dr4-septa~bus',
#    'url': 'https://github.com/septadev/GTFS/releases/download/v201808043/gtfs_public.zip#google_bus.zip',
#    'download_url': 'https://transitland-gtfs.s3.amazonaws.com/datastore-uploads/feed_version/e07e3cacbf185bb6f00fff68c20fc044f8548a18.zip',
#    'feedvalidator_url': None},
#   {'sha1': '7a1cd005d21987bc68ec50e73264437f05f16dc9',
#    'earliest_calendar_date': '2018-08-26',
#    'latest_calendar_date': '2019-02-23',
#    'md5': '8bc679e274ac6aff9b2a9e596617c3f7',
#    'tags': {},
#    'fetched_at': '2018-09-27T23:51:59.795Z',
#    'imported_at': None,
#    'import_level': 0,
#    'created_at': '2018-09-27T23:51:59.805Z',
#    'updated_at': '2018-09-27T23:52:00.036Z',
#    'feed_version_imports': [10712, 10695],
#    'feed_version_imports_url': 'https://api.transit.land/api/v1/feed_version_imports?feed_onestop_id=f-dr4-septa%7Ebus&feed_version_sha1=7a1cd005d21987bc68ec50e73264437f05f16dc9',
#    'feed_version_infos': [54328],
#    'import_status': 'in_progress',
#    'is_active_feed_version': False,
#    'changesets_imported_from_this_feed_version': [],
#    'feed': 'f-dr4-septa~bus',
#    'url': 'https://github.com/septadev/GTFS/releases/download/v201809091/gtfs_public.zip#google_bus.zip',
#    'download_url': 'https://transitland-gtfs.s3.amazonaws.com/datastore-uploads/feed_version/7a1cd005d21987bc68ec50e73264437f05f16dc9.zip',
#    'feedvalidator_url': None},
#   {'sha1': '15b4aed52638c8f8434f01c102f8dff24918576e',
#    'earliest_calendar_date': '2018-08-26',
#    'latest_calendar_date': '2019-02-23',
#    'md5': '934e275226278472f4aeffd6e9da5a42',
#    'tags': {'extend_to_date': '2020-02-23', 'extend_from_date': '2019-01-23'},
#    'fetched_at': '2018-10-04T23:44:17.649Z',
#    'imported_at': '2018-10-05T14:35:17.423Z',
#    'import_level': 4,
#    'created_at': '2018-10-04T23:44:17.660Z',
#    'updated_at': '2019-02-16T01:08:14.061Z',
#    'feed_version_imports': [10762],
#    'feed_version_imports_url': 'https://api.transit.land/api/v1/feed_version_imports?feed_onestop_id=f-dr4-septa%7Ebus&feed_version_sha1=15b4aed52638c8f8434f01c102f8dff24918576e',
#    'feed_version_infos': [54552],
#    'import_status': 'most_recent_succeeded',
#    'is_active_feed_version': True,
#    'changesets_imported_from_this_feed_version': [12638],
#    'feed': 'f-dr4-septa~bus',
#    'url': 'https://github.com/septadev/GTFS/releases/download/v201810010/gtfs_public.zip#google_bus.zip',
#    'download_url': 'https://transitland-gtfs.s3.amazonaws.com/datastore-uploads/feed_version/15b4aed52638c8f8434f01c102f8dff24918576e.zip',
#    'feedvalidator_url': None}],
#  'meta': {'sort_key': 'id', 'sort_order': 'asc', 'per_page': 999, 'offset': 0}}

# %%
try:
    nfeeds = (len(feeds["feed_versions"]))
    if nfeeds > 0:

        # looping over feed versions
        i = nfeeds - 1
        while i >= 0: 

            # grabbing date info
            date_fetched_iso8601 = feeds["feed_versions"][i]["fetched_at"]
            date_fetched = str(date_fetched_iso8601)[0:10]
            date_fetched_int = 10000 * int(date_fetched[0:4]) + 100 * int(date_fetched[5:7]) + int(date_fetched[8:10])

            # checking if before the input date
            if date_fetched_int < input_date_int:

                # output info
                date_fetched = date_fetched
                earliest_calendar_date = feeds["feed_versions"][i]["earliest_calendar_date"]
                latest_calendar_date = feeds["feed_versions"][i]["latest_calendar_date"]
                transitland_historical_url = feeds["feed_versions"][i]["download_url"]
                feed_id = feeds["feed_versions"][i]["feed"]                    
                output_feed_info.append([operator_name, operator_website, operator_state, operator_metro, operator_timezone, feed_id, date_fetched, earliest_calendar_date, latest_calendar_date, transitland_historical_url])

                break # break since this should be the most recent

            else:
                None

            i = i - 1

except:
    None

# make sub directory for the GTFS
os.makedirs("../gtfs/feeds_" + input_date, exist_ok=True)

# write this info to a csv file, downloading the GTFS at the same time
gtfs_zips_to_dl = []
with open("../gtfs/feeds_" + input_date + "/" + region + "_feed_info_" + input_date + ".csv", "w") as csvfile:
    writer = csv.writer(csvfile)
    for row in output_feed_info:
        writer.writerow(row)
        gtfs_zip = [row[5],row[9]]
        if gtfs_zip not in gtfs_zips_to_dl:
            gtfs_zips_to_dl.append(gtfs_zip)

for gtfs_zip in gtfs_zips_to_dl:
    print(gtfs_zip)
    try:
        urllib.request.urlretrieve(gtfs_zip[1], "../gtfs/feeds_" + input_date + "/" + input_date + "_" + gtfs_zip[0] + ".zip")
        sleep(1)
    except:
        None
# Out:
# ['transitland_feed_id', 'transitland_historical_url']
# ['f-dr4-septa~bus', 'https://transitland-gtfs.s3.amazonaws.com/datastore-uploads/feed_version/15b4aed52638c8f8434f01c102f8dff24918576e.zip']
